# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

matches_df = pd.read_csv('/content/drive/My Drive/ipl_data/matches.csv')
print(matches_df.head())

# %%
deliveries_df = pd.read_csv('/content/drive/My Drive/ipl_data/deliveries.csv')
print(deliveries_df.head())
